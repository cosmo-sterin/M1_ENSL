# %%
import matplotlib.pyplot as plt
import PIL.Image as Image
# %matplotlib inline

# %%
import csv
def load_histo(name):
    f = open(name,"r")

    histo = csv.reader(f)

    x = []
    y = []
    for (i,row) in enumerate(histo):
        if i == 0:
            continue
        x.append(int(row[0]))
        y.append(float(row[1]))
    f.close()
    return x,y

# %% [markdown]
# # Lena and its histogram

# %%
Image.open("../../data/tp2/len_dark.pgm")
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=256x256 at 0x7F4D396B72B0>

# %%
x_len,y_len=load_histo("results/histo_lendark.csv")

# %%
plt.bar(x_len,y_len)
plt.title("Histogram of dark lena")
plt.show()

# %% [markdown]
# # Lena, Histogram inversion

# %%
x_inv,y_inv=load_histo("results/histo_lenwhite.csv")

# %%
plt.bar(x_len,y_len,label='dark lena')
plt.bar(x_inv,y_inv,label='inversed dark lena')
plt.legend()
plt.title("Histogram of len_dark.pgm after inversion")
plt.show()

# %%
Image.open("results/len_white.pgm")
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=256x256 at 0x7F4D39A327B8>

# %% [markdown]
# # Lena, Gamma-correction

# %% [markdown]
# ## Gamma 2.2

# %%
x_g22,y_g22=load_histo("results/histo_leng22.csv")

# %%
plt.bar(x_len,y_len,label='dark lena')
plt.bar(x_g22,y_g22,label='gamma 2.2 dark lena')
plt.legend()
plt.title("Histogram of len_dark.pgm after 2.2 gamma correct")
plt.show()

# %%
Image.open("results/len_g22.pgm")
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=256x256 at 0x7F4D39029080>

# %% [markdown]
# ## Gamma 1/2.2

# %%
x_g1o22,y_g1o22=load_histo("results/histo_leng1o22.csv")

# %%
plt.bar(x_len,y_len,label='dark lena')
plt.bar(x_g1o22,y_g1o22,label='gamma 2.2 dark lena')
plt.legend()
plt.title("Histogram of len_dark.pgm after 1/2.2 gamma correct")
plt.show()

# %%
Image.open("results/len_g1o22.pgm")
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=256x256 at 0x7F4D391CB320>

# %% [markdown]
# # Lena Equalization

# %%
x_equa,y_equa=load_histo("results/histo_lenequa.csv")

# %%
plt.bar(x_len,y_len,label='dark lena')
plt.bar(x_equa,y_equa,label='dark lena equalized')
plt.legend()
plt.title("Histogram of len_dark.pgm after equalization")
plt.show()

# %%
Image.open("results/len_equa.pgm")
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=256x256 at 0x7F4D3A4774E0>
